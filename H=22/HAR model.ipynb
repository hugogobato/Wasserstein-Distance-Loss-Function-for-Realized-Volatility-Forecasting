# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
df = pd.read_excel("SP100_vol.xlsx", index_col="Date",parse_dates=True)

# %%
df.head()
# Out:
#                  AMT       COP       CVX       AXP       BAC         C  \
# Date
# 2000-01-04  0.014124  0.018373  0.015768  0.012207  0.010291  0.015468
# 2000-01-05  0.015762  0.011954  0.011587  0.010778  0.011098  0.013562
# 2000-01-06  0.011944  0.014456  0.012986  0.013216  0.008582  0.012972
# 2000-01-07  0.009732  0.009799  0.008922  0.009994  0.006183  0.010277
# 2000-01-10  0.009956  0.007930  0.007381  0.009133  0.005680  0.007148
#
#                   CB       CME        GS       JPM  ...       TMO       UNH  \
# Date                                                ...
# 2000-01-04  0.009848  0.014583  0.017107  0.013571  ...  0.015377  0.013590
# 2000-01-05  0.009857  0.010666  0.014501  0.012888  ...  0.011744  0.010659
# 2000-01-06  0.010098  0.012094  0.014643  0.013615  ...  0.011072  0.015759
# 2000-01-07  0.006879  0.009909  0.010316  0.008367  ...  0.009402  0.008731
# 2000-01-10  0.009542  0.018029  0.009381  0.007802  ...  0.009832  0.008183
#
# ...

# %%
train=df.iloc[:int(len(df)*0.7)]

# %%
test=df.iloc[int(len(df)*0.7)-22:]

# %%
df.iloc[int(len(df)*0.7)]
# Out:
# AMT     0.008684
# COP     0.011713
# CVX     0.008553
# AXP     0.015038
# BAC     0.009973
#           ...
# MCD     0.004191
# NKE     0.011698
# SBUX    0.007688
# TGT     0.010126
# TJX     0.007017
# Name: 2009-07-01 00:00:00, Length: 80, dtype: float64

# %%
train=np.array(train)

# %%
train.shape
# Out:
# (2386, 80)

# %%
RV_d = []
for i in range(len(train)-1):
  RV_d.append(train[i].astype(float))

RV_w = []
for i in range(len(train)-5):
  RV_w.append(np.mean(train[i:i+5]).astype(float))

RV_m = []
for i in range(len(train)-22):
  RV_m.append(np.mean(train[i:i+22]).astype(float))

RV_d=RV_d[len(RV_d)-len(RV_m):]
RV_w=RV_w[len(RV_w)-len(RV_m):]

# %%
RV_D = np.zeros([len(RV_d),train.shape[1]])
for i in range(len(RV_d)):
  RV_D[i,:]=RV_d[i]

RV_W = np.zeros([len(RV_w),train.shape[1]])
for i in range(len(RV_w)):
  RV_W[i,:]=RV_w[i]

RV_M = np.zeros([len(RV_m),train.shape[1]])
for i in range(len(RV_m)):
  RV_M[i,:]=RV_m[i]

# %%
RV_actuals=train[22:,:]

# %%
RV_actuals.shape
# Out:
# (2364, 80)

# %%
test=np.array(test)

# %%
test.shape
# Out:
# (1045, 80)

# %%
  for i in range(len(test)-1):
    RV_d.append(test[i].astype(float))

  RV_w = []
  for i in range(len(test)-5):
    RV_w.append(np.mean(test[i:i+5]).astype(float))

  RV_m = []
  for i in range(len(test)-22):
    RV_m.append(np.mean(test[i:i+22]).astype(float))

  RV_d=RV_d[len(RV_d)-len(RV_m):]
  RV_w=RV_w[len(RV_w)-len(RV_m):]
  RV_D_test = np.zeros([len(RV_d),test.shape[1]])
  for i in range(len(RV_d)):
    RV_D_test[i,:]=RV_d[i]

  RV_W_test = np.zeros([len(RV_w),test.shape[1]])
  for i in range(len(RV_w)):
    RV_W_test[i,:]=RV_w[i]

  RV_M_test = np.zeros([len(RV_m),test.shape[1]])
  for i in range(len(RV_m)):
    RV_M_test[i,:]=RV_m[i]

# %%
forecasts=np.zeros([test.shape[0]-22,test.shape[1]])
for j in range(test.shape[1]):
  Data ={'Actual': RV_actuals[:,j],
  'D': RV_D[:,j],
  'W': RV_W[:,j],
  'M': RV_M[:,j]}
  dataframe = pd.DataFrame(data=Data)
  rv_scaled=dataframe
  rv_scaled = sm.add_constant(rv_scaled)
  rv_scaled['Actual']=rv_scaled['Actual'].astype(float)
  rv_scaled['D']=rv_scaled['D'].astype(float)
  rv_scaled['W']=rv_scaled['W'].astype(float)
  rv_scaled['M']=rv_scaled['M'].astype(float)
  X = rv_scaled.drop("Actual", axis = 1)
  y = rv_scaled["Actual"]
  results = sm.OLS(y, X).fit()
  Data ={'D': RV_D_test[:,j],
  'W': RV_W_test[:,j],
  'M': RV_M_test[:,j]}
  dataframe = pd.DataFrame(data=Data)
  rv_scaled=dataframe
  X_test = sm.add_constant(rv_scaled)
  for i in range(int(len(X_test)/22)):
    forecasts1=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*X_test[X_test.columns[1]][i*22]
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22,j]=forecasts1
    forecasts2=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts1
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+1,j]=forecasts2
    forecasts3=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts2
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+2,j]=forecasts3
    forecasts4=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts3
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+3,j]=forecasts4
    forecasts5=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts4
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+4,j]=forecasts5
    forecasts6=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts5
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+5,j]=forecasts6
    forecasts7=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts6
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+6,j]=forecasts7
    forecasts8=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts7
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+7,j]=forecasts8
    forecasts9=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts8
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+8,j]=forecasts9
    forecasts10=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts9
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+9,j]=forecasts10
    forecasts11=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts10
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+10,j]=forecasts11
    forecasts12=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts11
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+11,j]=forecasts12
    forecasts13=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts12
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+12,j]=forecasts13
    forecasts14=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts13
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+13,j]=forecasts14
    forecasts15=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts14
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+14,j]=forecasts15
    forecasts16=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts15
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+15,j]=forecasts16
    forecasts17=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts16
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+16,j]=forecasts17
    forecasts18=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts17
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+17,j]=forecasts18
    forecasts19=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts18
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+18,j]=forecasts19
    forecasts20=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts19
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+19,j]=forecasts20
    forecasts21=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts20
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+20,j]=forecasts21
    forecasts22=(results.params[0]*X_test[X_test.columns[0]][i*22]+results.params[1]*forecasts21
                  +results.params[2]*X_test[X_test.columns[2]][i*22]+results.params[3]*X_test[X_test.columns[3]][i*22])
    forecasts[i*22+21,j]=forecasts22

# %%
forecasts.shape
# Out:
# (1023, 80)

# %%
df1=df.iloc[int(len(df)*0.7):]

# %%
df1.head()
# Out:
#                  AMT       COP       CVX       AXP       BAC         C  \
# Date
# 2009-07-01  0.008684  0.011713  0.008553  0.015038  0.009973  0.010190
# 2009-07-02  0.005333  0.013754  0.009606  0.009791  0.011717  0.009124
# 2009-07-06  0.007305  0.009744  0.007956  0.006219  0.014207  0.009040
# 2009-07-07  0.005686  0.009516  0.006491  0.005460  0.011123  0.009362
# 2009-07-08  0.006191  0.016867  0.009998  0.007953  0.014055  0.011115
#
#                   CB       CME        GS       JPM  ...       TMO       UNH  \
# Date                                                ...
# 2009-07-01  0.006542  0.007843  0.009500  0.007578  ...  0.006517  0.008160
# 2009-07-02  0.005080  0.008150  0.009581  0.008267  ...  0.006502  0.006875
# 2009-07-06  0.004838  0.009033  0.008960  0.008200  ...  0.006311  0.006555
# 2009-07-07  0.006507  0.008783  0.008505  0.008336  ...  0.006162  0.007088
# 2009-07-08  0.011037  0.008396  0.010142  0.008328  ...  0.016428  0.006435
#
# ...

# %%
for i in range(len(df1.columns)):
  df1[df1.columns[i]]=forecasts[:,i]
# Out:
# <ipython-input-20-8a232fbfd1e1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[df1.columns[i]]=forecasts[:,i]

# %%
df1.to_excel("HAR Forecasts.xlsx")
